# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO26n model
model = YOLO("./best.pt")


# Run inference with the YOLO26n model on the 'bus.jpg' image
results = model("./1772184786855.png")
# Visualize the results
for result in results:
    result.show()
# Out:
# image 1/1 c:\Users\Admin\Desktop\WebRobot\1772184786855.png: 384x640 2 Cubic_Blacks, 1 Cubic_Red, 1 Cubic_Yellow, 1 Cylinder_Black, 1 Cylinder_Red, 1 Cylinder_Yellow, 1 Pentagonal_Dice_Red, 2 Pentagonal_Dice_Yellows, 133.8ms
# Speed: 5.8ms preprocess, 133.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
